# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('survey_results_public1.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Age']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3        25.0
# 4        31.0
# 5         NaN
# 6         NaN
# 7        36.0
# 8        30.0
# 9        22.0
# 10       23.0
# 11       49.0
# 12       53.0
# 13       27.0
# 14        NaN
# 15       45.0
# 16       25.0
# 17       32.0
# 18       24.0
# 19       40.0
# 20       23.0
# 21        NaN
# 22       27.0
# 23       45.0
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28       18.0
# 29        NaN
#          ...
# 64431     NaN
# 64432     NaN
# 64433    64.0
# 64434     NaN
# 64435     NaN
# 64436     NaN
# 64437     NaN
# 64438     NaN
# 64439     NaN
# 64440     NaN
# 64441    17.0
# 64442     NaN
# 64443     NaN
# 64444     NaN
# 64445     NaN
# 64446     NaN
# 64447     NaN
# 64448     NaN
# 64449     NaN
# 64450     NaN
# 64451     NaN
# 64452     NaN
# 64453     NaN
# 64454     NaN
# 64455     NaN
# 64456     NaN
# 64457     NaN
# 64458     NaN
# 64459     NaN
# 64460     NaN
# ...

# %%
df['Country']
# Out:
# 0                   Germany
# 1            United Kingdom
# 2        Russian Federation
# 3                   Albania
# 4             United States
# 5                   Germany
# 6                     India
# 7             United States
# 8                   Tunisia
# 9            United Kingdom
# 10           United Kingdom
# 11                    Spain
# 12              Netherlands
# 13            United States
# 14                   France
# 15           United Kingdom
# 16            United States
# 17            United States
# 18            United States
# 19                    Spain
# 20                  Belgium
# 21                    India
# 22                  Germany
# 23                  Germany
# 24                 Portugal
# 25                   Canada
# 26            United States
# 27                    China
# 28                  Ukraine
# 29           United Kingdom
#                 ...
# 64431                   NaN
# 64432        United Kingdom
# ...

# %%
ind=df.loc[df['Country']=='India']

# %%
ind['Age']
# Out:
# 6         NaN
# 21        NaN
# 57        NaN
# 62       21.0
# 147      36.0
# 175       NaN
# 225      24.0
# 230      20.0
# 232      22.0
# 266       NaN
# 272      26.0
# 277       NaN
# 320      24.0
# 362      23.0
# 374       NaN
# 405      21.0
# 412      24.0
# 472      25.0
# 491       NaN
# 522      23.0
# 551       NaN
# 580       NaN
# 589      27.0
# 595      31.0
# 622      26.0
# 629      21.0
# 671       NaN
# 696       NaN
# 721      30.0
# 750      20.0
#          ...
# 64036     NaN
# 64040     NaN
# 64048     NaN
# 64053     NaN
# 64055     NaN
# 64056     NaN
# 64060     NaN
# 64071     NaN
# 64098     NaN
# 64111     NaN
# 64117     NaN
# 64208     NaN
# 64219     NaN
# 64261     NaN
# 64278    35.0
# 64280    20.0
# 64301     NaN
# 64303     NaN
# 64305     NaN
# 64307     NaN
# 64311     NaN
# 64337     NaN
# 64350     NaN
# 64374     NaN
# 64381    20.0
# 64391     NaN
# 64398     NaN
# 64439     NaN
# 64442     NaN
# 64452     NaN
# ...

# %%
ind.dropna(inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df["Age"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3        25.0
# 4        31.0
# 5         NaN
# 6         NaN
# 7        36.0
# 8        30.0
# 9        22.0
# 10       23.0
# 11       49.0
# 12       53.0
# 13       27.0
# 14        NaN
# 15       45.0
# 16       25.0
# 17       32.0
# 18       24.0
# 19       40.0
# 20       23.0
# 21        NaN
# 22       27.0
# 23       45.0
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28       18.0
# 29        NaN
#          ...
# 64431     NaN
# 64432     NaN
# 64433    64.0
# 64434     NaN
# 64435     NaN
# 64436     NaN
# 64437     NaN
# 64438     NaN
# 64439     NaN
# 64440     NaN
# 64441    17.0
# 64442     NaN
# 64443     NaN
# 64444     NaN
# 64445     NaN
# 64446     NaN
# 64447     NaN
# 64448     NaN
# 64449     NaN
# 64450     NaN
# 64451     NaN
# 64452     NaN
# 64453     NaN
# 64454     NaN
# 64455     NaN
# 64456     NaN
# 64457     NaN
# 64458     NaN
# 64459     NaN
# 64460     NaN
# ...

# %%
df.dropna(inplace=True)

# %%
ind['Age']
# Out:
# 622      26.0
# 2042     28.0
# 3218     24.0
# 3635     25.0
# 5737     25.0
# 5934     22.0
# 5942     29.0
# 6067     22.0
# 6075     23.0
# 6087     30.0
# 6095     46.0
# 6108     24.0
# 6298     25.0
# 6347     29.0
# 6440     22.0
# 6538     32.0
# 6571     25.0
# 6763     28.0
# 6851     27.0
# 6898     26.0
# 7012     27.0
# 7061     28.0
# 7091     30.0
# 7122     35.0
# 7141     30.0
# 7530     32.0
# 7658     30.0
# 7793     23.0
# 7807     24.0
# 7845     25.0
#          ...
# 46347    23.0
# 46400    28.0
# 46722    27.0
# 47599    24.0
# 47618    26.0
# 48004    35.0
# 48054    26.0
# 48090    24.0
# 49259    26.0
# 50513    26.0
# 50609    24.0
# 50856    31.0
# 50875    24.0
# 51775    30.0
# 51819    25.0
# 52047    28.0
# 52458    29.0
# 53695    25.0
# 53871    25.0
# 54209    23.0
# 54254    39.0
# 54545    22.0
# 55597    25.0
# 55706    31.0
# 56526    23.0
# 57281    23.0
# 58697    24.0
# 59524    28.0
# 60727    45.0
# 60885    33.0
# ...

# %%
plt.xlabel("Age")
plt.ylabel("Total")
plt.title("Histogram of age")
arr=[10,20,30,40,50,60,70,80,90]
plt.hist(df['Age'],bins=arr,edgecolor='orange')
# Out:
# (array([1.400e+01, 1.823e+03, 1.705e+03, 5.480e+02, 1.150e+02, 7.000e+00,
#         1.000e+00, 0.000e+00]),
#  array([10, 20, 30, 40, 50, 60, 70, 80, 90]),
#  <a list of 8 Patch objects>)

# %%
a=df['Gender'].value_counts()
two=a.head(2)
label=['Man','Women']
plt.pie(two,labels=label,autopct="%.1f%%",shadow=True,radius=10)
plt.legend(label)
plt.axis('equal')
plt.show()

# %%
df['Age1stCode']
df.dropna(inplace=True)
df['Age1stCode'].max
# Out:
# <bound method Series.max of 9        14
# 32       14
# 41       14
# 46       10
# 68       12
# 79       11
# 94       21
# 117      15
# 121      12
# 126      14
# 129      11
# 149      10
# 156      18
# 159      14
# 165      15
# 168      17
# 177      16
# 185      12
# 193      13
# 198       9
# 203      15
# 205      10
# 212      16
# 213      16
# 231      14
# 240      11
# 253      13
# 254      12
# 260      10
# 267      21
#          ..
# 61233    10
# 61242    14
# 61272    12
# 61283    16
# 61291    12
# 61292    18
# 61298    16
# 61308    15
# 61357     9
# 61369    17
# 61408    19
# 61431    16
# 61439    25
# 61499    14
# 61500    11
# 61501    10
# 61507    25
# 61518    14
# 61538    13
# 61555     9
# 61564    10
# 61568    16
# 61586     9
# 61594    14
# 61596    15
# 61613    11
# 61636    24
# 61654    24
# 61993    16
# 63517    13
# Name: Age1stCode, Length: 4213, dtype: object>

# %%
plt.xlabel("Age")
plt.ylabel("Total")
plt.title("Histogram of age")
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.hist(df['Age1stCode'],edgecolor='red')
plt.rcParams['figure.figsize']=[100,5]
